# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv". Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
ruta_archivo = r"C:\Users\migue\OneDrive\Documentos\GitHub\ONLINE_DS_THEBRIDGE_Miguel_repo_test\Sprint_08\Unidad_01\Practica_Obligatoria\data\california_cities.csv"
california_cities = pd.read_csv(ruta_archivo)

# copia 
california_cities_copy = california_cities.copy()

# ver
print("Primeras filas del dataset original:")
print(california_cities.head())
# Out:
# Primeras filas del dataset original:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
print("\nDescripción estadística del dataset:")
print(california_cities.describe())
# Out:
# Descripción estadística del dataset:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  482.000000  482.000000  482.000000   434.000000    470.000000
# mean   240.500000   36.095088 -119.837714   180.416705    567.168723
# std    139.285678    2.298006    2.147676   309.531825   1001.265722
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    120.250000   33.977292 -121.954931    22.000000     69.000000
# 50%    240.500000   36.204722 -119.708611    67.000000    200.000000
# 75%    360.750000   37.886667 -117.977292   173.500000    515.000000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.820000e+02        480.000000       482.000000        481.000000
# mean       6.489493e+04         18.442183        16.840981          1.589630
# ...

# %%
# eliminar las filas con val nulos
california_cities_cleaned = california_cities_copy.dropna()

# ver
print("\nPrimeras filas del dataset limpio:")
print(california_cities_cleaned.head())
# Out:
# Primeras filas del dataset limpio:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
# 5           5   AlisoViejo  33.575000 -117.725556        127.0         417.0
# 6           6      Alturas  41.487222 -120.542500       1332.0        4370.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 4             83089             7.632            7.631             0.001
# 5             47823             7.472            7.472             0.000
# 6              2827             2.449            2.435             0.014
#
# ...

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand itc", tamaño 18, color azul acero)
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %%
print(california_cities_copy.head(50))
# Out:
#     Unnamed: 0            city       latd       longd  elevation_m  \
# 0            0        Adelanto  34.576111 -117.432778        875.0
# 1            1     AgouraHills  34.153333 -118.761667        281.0
# 2            2         Alameda  37.756111 -122.274444          NaN
# 3            3          Albany  37.886944 -122.297778          NaN
# 4            4        Alhambra  34.081944 -118.135000        150.0
# 5            5      AlisoViejo  33.575000 -117.725556        127.0
# 6            6         Alturas  41.487222 -120.542500       1332.0
# 7            7      AmadorCity  38.419444 -120.824167        280.0
# 8            8  AmericanCanyon  38.168056 -122.252500         14.0
# 9            9         Anaheim  33.836111 -117.889722         48.0
# 10          10        Anderson  40.452222 -122.296667        132.0
# 11          11      AngelsCamp  38.068333 -120.539722        420.0
# 12          12         Antioch  38.005000 -121.805833         13.0
# ...

# %%
top_populated_cities = california_cities_copy.nlargest(10, 'population_total')
print(top_populated_cities[['city', 'population_total']])
# Out:
#              city  population_total
# 239    LosAngeles           3884307
# 367      SanDiego           1345895
# 375       SanJose           1000536
# 370  SanFrancisco            837442
# 150        Fresno            509039
# 359    Sacramento            466488
# 234     LongBeach            462257
# 290       Oakland            406253
# 26    Bakersfield            347483
# 9         Anaheim            336000

# %%
# 1) ciudades más pobladas
top_cities = california_cities_cleaned.nlargest(5, 'population_total')

# (Colores: azul, gris, aceituna, marrón, con trasparencia)
colors = ['blue', 'gray', 'olive', 'brown', (0.5, 0.5, 0.5, 0.5)]  # Transparente al final

# grafico barras
plt.figure(figsize=(8, 6))
bars = plt.bar(top_cities['city'], top_cities['population_total'], color=colors)

# poner los num de población encima de las barras
for bar, population in zip(bars, top_cities['population_total']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             f"{population:,}", ha='center', va='bottom', fontsize=10)

# titulos y nombres del grafico
plt.title("Ciudades más pobladas de California")
plt.ylabel("Número de habitantes")
plt.show()

# %%
top_area_cities = california_cities_copy.nlargest(10, 'area_total_km2')
print(top_area_cities[['city', 'area_total_km2']])
# Out:
#                city  area_total_km2
# 239      LosAngeles        1302.000
# 367        SanDiego         964.510
# 55   CaliforniaCity         527.401
# 375         SanJose         466.109
# 26      Bakersfield         371.946
# 150          Fresno         290.877
# 303        Palmdale         275.099
# 359      Sacramento         259.273
# 305     PalmSprings         245.984
# 215       Lancaster         244.876

# %%
# 2) histograma del área total
plt.figure(figsize=(8, 6))
plt.hist(california_cities_cleaned['area_total_km2'], bins=50, color='steelblue', edgecolor='black', alpha=0.7)

# titulos y nombres del grafico
plt.title("Histograma del área total ocupada por las ciudades", fontname="Bradley Hand ITC", fontsize=18)
plt.xlabel("Superficie (km²)")
plt.ylabel("Número de ciudades")
plt.show()

# %%
water_area_population = california_cities_copy[['city', 'area_water_km2', 'population_total']]
print(water_area_population)
# Out:
#             city  area_water_km2  population_total
# 0       Adelanto           0.046             31765
# 1    AgouraHills           0.076             20330
# 2        Alameda          31.983             75467
# 3         Albany           9.524             18969
# 4       Alhambra           0.003             83089
# ..           ...             ...               ...
# 477   Yountville           0.000              2933
# 478        Yreka           0.188              7765
# 479     YubaCity           0.201             64925
# 480      Yucaipa           0.013             51367
# 481  YuccaValley           0.000             20700
#
# [482 rows x 3 columns]

# %%
# 3) scatter de área de agua de un ciudad con su poblacion
plt.figure(figsize=(8, 6))
plt.scatter(california_cities_cleaned['area_water_km2'], california_cities_cleaned['population_total'],
            color='green', alpha=0.6, edgecolors='black')

# posibles outliers
outliers = california_cities_cleaned[
    (california_cities_cleaned['area_water_km2'] > 80) & (california_cities_cleaned['population_total'] > 3000)
]

# líneas y etiquetar los outliers
for _, row in outliers.iterrows():
    plt.plot([row['area_water_km2'], row['area_water_km2']],
             [0, row['population_total']], color='black', linestyle='--', linewidth=1)
    plt.text(row['area_water_km2'], row['population_total'], "Outliers", fontsize=10)


# titulos y nombres del grafico
plt.title("Población por kilómetro cuadrado de agua")
plt.xlabel("Área de agua en la ciudad (km²)")
plt.ylabel("Población")
plt.grid(alpha=0.3)
plt.show()

# %%
city_elevation = california_cities_copy[['city', 'elevation_m']]
print(city_elevation)
# Out:
#             city  elevation_m
# 0       Adelanto        875.0
# 1    AgouraHills        281.0
# 2        Alameda          NaN
# 3         Albany          NaN
# 4       Alhambra        150.0
# ..           ...          ...
# 477   Yountville         30.0
# 478        Yreka        787.0
# 479     YubaCity         18.0
# 480      Yucaipa        798.0
# 481  YuccaValley       1027.0
#
# [482 rows x 2 columns]

# %%
#boxplot de la altura de las ciudades.
plt.figure(figsize=(8, 6))
sns.boxplot(x=california_cities_cleaned['elevation_m'], color='red')

# Personalizar el gráfico
plt.title("Diagrama de caja de la Altitud de las ciudades de California")
plt.xlabel("Altitud (m)")
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Gráfico de barras
axes[0, 0].bar(top_cities['city'], top_cities['population_total'], color=colors)
for bar, population in zip(axes[0, 0].patches, top_cities['population_total']):
    axes[0, 0].text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
                    f"{population:,}", ha='center', va='bottom', fontsize=10)
axes[0, 0].set_title("Ciudades más pobladas de California")
axes[0, 0].set_ylabel("Número de habitantes")

# Histograma
axes[0, 1].hist(california_cities_cleaned['area_total_km2'], bins=50, color='steelblue', edgecolor='black', alpha=0.7)
axes[0, 1].set_title("Histograma del área total ocupada por las ciudades", fontname="Bradley Hand ITC", fontsize=12)
axes[0, 1].set_xlabel("Superficie (km²)")
axes[0, 1].set_ylabel("Número de ciudades")

# Scatterplot
axes[1, 0].scatter(california_cities_cleaned['area_water_km2'], california_cities_cleaned['population_total'],
                   color='green', alpha=0.6, edgecolors='black')
for _, row in outliers.iterrows():
    axes[1, 0].plot([row['area_water_km2'], row['area_water_km2']],
                    [0, row['population_total']], color='black', linestyle='--', linewidth=1)
    axes[1, 0].text(row['area_water_km2'], row['population_total'], "Outliers", fontsize=10)
axes[1, 0].set_title("Población por kilómetro cuadrado de agua")
axes[1, 0].set_xlabel("Área de agua en la ciudad (km²)")
axes[1, 0].set_ylabel("Población")
axes[1, 0].grid(alpha=0.3)
# Boxplot
sns.boxplot(ax=axes[1, 1], x=california_cities_cleaned['elevation_m'], color='red')
axes[1, 1].set_title("Diagrama de caja de la Altitud de las ciudades de California")
axes[1, 1].set_xlabel("Altitud (m)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.

# %%
plt.savefig(r"C:\Users\migue\OneDrive\Documentos\GitHub\ONLINE_DS_THEBRIDGE_Miguel_repo_test\Sprint_08\Unidad_01\Practica_Obligatoria\figura_california_cities.png", dpi=300)
plt.show()
